# %% [markdown]
# ## Captura e Visualização de dados

# %% [markdown]
# <b>Professor:</b> Diénert Vieira
# <b>Telefone:</b> (83) 9 8182-1479
# <b>Email:</b> dienertalencar@gmail.com

# %% [markdown]
# ### Segunda avaliação de aprendizagem

# %% [markdown]
# Para consolidar os conhecimentos adquiridos no 1º fim de semana do módulo, vamos desenvolver uma análise em cima de dados que todos temos, nossos extratos bancários ou de cartão de crédito, realizar o parsing em cima de arquivos que faremos o download (não vamos fazer a captura, mas vamos aproveitar a tecnologia que já vimos) e gerar visualizações para esses dados.

# %% [markdown]
# * Para completar esse notebook, substitua onde houver 'None' nos códigos com o código que você julgar mais adequado.
# * Em algumas células podem existir algumas dicas, passe o mouse sobre elas caso queira uma ajuda na solução.

# %% [markdown]
# ### Tarefa 01
# #### Fazer o download de 1 extrato (cartão de crédito ou conta corrente) de um mês de 2019
# <img align="right" src="imagens/exportar.png">
#
# * Acesse a sua conta pela web (exemplo com o Banco do Brasil)
# * No menu procure por cartões > Extrato (em Fatura)
# * Escolha o cartão
# * Escolha o mês
# * Clique no ícone de exportar, no topo da página, como na figura:
# * Escolha o formato OFX
# * Salve o arquivo na pasta 'dados/cartao' ou 'dados/conta'

# %% [markdown]
# #### Extrair os dados desses arquivos, ou seja, fazer o parsing dos arquivos usando a tecnologia vista em sala, através do scrapy, usando <u>css selector</u>  ou <u>xpath</u>. Para isso, você precisa entender a estrutura do arquivo OFX para saber como extrair as informações.

# %% [markdown]
# Primeiro, vamos abrir esse arquivo. Coloque na variável path, o caminho relativo para o mês que você extraiu:

# %%
path = '../../2018-04.ofx'

# %% [markdown]
# Abra este arquivo:

# %% [markdown]
# Exemplo:
#
# ```python
# path = '../dados/cartao/OUROCARD_VISA_INTERNATIONAL-Out_19.ofx'
# ```

# %%
ofx = open(path)

# %% [markdown]
# Exiba a lista de todas as linhas do arquivo:

# %%
ofx.readlines()
# Out:
# ['OFXHEADER:100\n',
#  'DATA:OFXSGML\n',
#  'VERSION:102\n',
#  'SECURITY:NONE\n',
#  'ENCODING:UTF-8\n',
#  'CHARSET:1252\n',
#  'COMPRESSION:NONE\n',
#  'OLDFILEUID:NONE\n',
#  'NEWFILEUID:NONE\n',
#  '<OFX>\n',
#  '  <SIGNONMSGSRSV1>\n',
#  '    <SONRS>\n',
#  '      <STATUS>\n',
#  '        <CODE>0</CODE>\n',
#  '        <SEVERITY>INFO</SEVERITY>\n',
#  '      </STATUS>\n',
#  '      <DTSERVER>20180430120030[-3:BRT]</DTSERVER>\n',
#  '      <LANGUAGE>POR</LANGUAGE>\n',
#  '      <FI>\n',
#  '        <ORG>Gerencianet</ORG>\n',
#  '        <FID>gnt</FID>\n',
#  '      </FI>\n',
#  '    </SONRS>\n',
#  '  </SIGNONMSGSRSV1>\n',
#  '  <BANKMSGSRSV1>\n',
#  '    <STMTTRNRS>\n',
#  '      <TRNUID>1</TRNUID>\n',
#  '      <STATUS>\n',
#  '        <CODE>0</CODE>\n',
#  '        <SEVERITY>INFO</SEVERITY>\n',
#  '      </STATUS>\n',
#  '      <STMTRS>\n',
#  '        <CURDEF>BRL</CURDEF>\n',
#  '        <BANKACCTFROM>\n',
#  '          <BANKID>gnt</BANKID>\n',
#  '          <ACCTID>1459950-11</ACCTID>\n',
#  '          <ACCTTYPE>CHECKING</ACCTTYPE>\n',
#  '        </BANKACCTFROM>\n',
#  '        <BANKTRANLIST>\n',
#  '          <DTSTART>20180130120000[-3:BRT]</DTSTART>\n',
#  '          <DTEND>20180429120000[-3:BRT]</DTEND>\n',
#  '          <STMTTRN>\n',
#  '            <TRNTYPE>CREDIT</TRNTYPE>\n',
#  '            <DTPOSTED>20180309120000[-3:BRT]</DTPOSTED>\n',
#  '            <TRNAMT>74,40</TRNAMT>\n',
#  '            <FITID>2018030607232002046000000061553574</FITID>\n',
#  '            <CHECKNUM>000000061553574</CHECKNUM>\n',
#  '            <REFNUM>2002046000000017223405</REFNUM>\n',
#  '            <MEMO>Repasse pagamento: 17223405 de Jorge Teixeira</MEMO>\n',
#  '          </STMTTRN>\n',
#  '          <STMTTRN>\n',
#  '            <TRNTYPE>DEBIT</TRNTYPE>\n',
#  '            <DTPOSTED>20180309120000[-3:BRT]</DTPOSTED>\n',
#  '            <TRNAMT>-3,34</TRNAMT>\n',
#  '            <FITID>2018030607231001046000000061553576</FITID>\n',
#  '            <CHECKNUM>000000061553576</CHECKNUM>\n',
#  '            <MEMO>Tarifa repasse: 17223405 de Jorge Teixeira</MEMO>\n',
#  '          </STMTTRN>\n',
#  '          <STMTTRN>\n',
#  '            <TRNTYPE>CREDIT</TRNTYPE>\n',
#  '            <DTPOSTED>20180320120000[-3:BRT]</DTPOSTED>\n',
#  '            <TRNAMT>74,40</TRNAMT>\n',
#  '            <FITID>2018031703312002046000000062976602</FITID>\n',
#  '            <CHECKNUM>000000062976602</CHECKNUM>\n',
#  '            <REFNUM>2002046000000022612776</REFNUM>\n',
#  '            <MEMO>Repasse pagamento: 22612776 de Paulo Jorge Alves</MEMO>\n',
#  '          </STMTTRN>\n',
#  '          <STMTTRN>\n',
#  '            <TRNTYPE>DEBIT</TRNTYPE>\n',
#  '            <DTPOSTED>20180320120000[-3:BRT]</DTPOSTED>\n',
#  '            <TRNAMT>-3,34</TRNAMT>\n',
#  '            <FITID>2018031703311001046000000062976603</FITID>\n',
#  '            <CHECKNUM>000000062976603</CHECKNUM>\n',
#  '            <MEMO>Tarifa repasse: 22612776 de Paulo Jorge Alves</MEMO>\n',
#  '          </STMTTRN>\n',
#  '          <STMTTRN>\n',
#  '            <TRNTYPE>CREDIT</TRNTYPE>\n',
#  '            <DTPOSTED>20180330120000[-3:BRT]</DTPOSTED>\n',
#  '            <TRNAMT>74,40</TRNAMT>\n',
#  '            <FITID>2018032704142002046000000063575983</FITID>\n',
#  '            <CHECKNUM>000000063575983</CHECKNUM>\n',
#  '            <REFNUM>2002046000000028015595</REFNUM>\n',
#  '            <MEMO>Repasse pagamento: 28015595 de Fulano Aguiar</MEMO>\n',
#  '          </STMTTRN>\n',
#  '          <STMTTRN>\n',
#  '            <TRNTYPE>DEBIT</TRNTYPE>\n',
#  '            <DTPOSTED>20180330120000[-3:BRT]</DTPOSTED>\n',
#  '            <TRNAMT>-3,34</TRNAMT>\n',
#  '            <FITID>2018032704141001046000000063575986</FITID>\n',
#  '            <CHECKNUM>000000063575986</CHECKNUM>\n',
#  '            <MEMO>Tarifa repasse: 28015595 de Fulano Aguiar</MEMO>\n',
#  '          </STMTTRN>\n',
#  '          <STMTTRN>\n',
#  '            <TRNTYPE>CREDIT</TRNTYPE>\n',
#  '            <DTPOSTED>20180406120000[-3:BRT]</DTPOSTED>\n',
#  '            <TRNAMT>65,10</TRNAMT>\n',
#  '            <FITID>2018040307262002046000000064109592</FITID>\n',
#  '            <CHECKNUM>000000064109592</CHECKNUM>\n',
#  '            <REFNUM>2002046000000028108174</REFNUM>\n',
#  '            <MEMO>Repasse pagamento: 28108174 de Ciclano da Silva</MEMO>\n',
#  '          </STMTTRN>\n',
#  '          <STMTTRN>\n',
#  '            <TRNTYPE>DEBIT</TRNTYPE>\n',
#  '            <DTPOSTED>20180406120000[-3:BRT]</DTPOSTED>\n',
#  '            <TRNAMT>-3,34</TRNAMT>\n',
#  '            <FITID>2018040307261001046000000064109593</FITID>\n',
#  '            <CHECKNUM>000000064109593</CHECKNUM>\n',
#  '            <MEMO>Tarifa repasse: 28108174 de Ciclano da Silva</MEMO>\n',
#  '          </STMTTRN>\n',
#  '          <STMTTRN>\n',
#  '            <TRNTYPE>CREDIT</TRNTYPE>\n',
#  '            <DTPOSTED>20180416120000[-3:BRT]</DTPOSTED>\n',
#  '            <TRNAMT>74,40</TRNAMT>\n',
#  '            <FITID>2018041303342002046000000065551500</FITID>\n',
#  '            <CHECKNUM>000000065551500</CHECKNUM>\n',
#  '            <REFNUM>2002046000000029384993</REFNUM>\n',
#  '            <MEMO>Repasse pagamento: 29384993 de Jorge Amado</MEMO>\n',
#  '          </STMTTRN>\n',
#  '          <STMTTRN>\n',
#  '            <TRNTYPE>DEBIT</TRNTYPE>\n',
#  '            <DTPOSTED>20180416120000[-3:BRT]</DTPOSTED>\n',
#  '            <TRNAMT>-3,34</TRNAMT>\n',
#  '            <FITID>2018041303341001046000000065551501</FITID>\n',
#  '            <CHECKNUM>000000065551501</CHECKNUM>\n',
#  '            <MEMO>Tarifa repasse: 29384993 de Jorge Amado</MEMO>\n',
#  '          </STMTTRN>\n',
#  '          <STMTTRN>\n',
#  '            <TRNTYPE>CREDIT</TRNTYPE>\n',
#  '            <DTPOSTED>20180417120000[-3:BRT]</DTPOSTED>\n',
#  '            <TRNAMT>55,80</TRNAMT>\n',
#  '            <FITID>2018041403362002046000000065642576</FITID>\n',
#  '            <CHECKNUM>000000065642576</CHECKNUM>\n',
#  '            <REFNUM>2002046000000029447637</REFNUM>\n',
#  '            <MEMO>Repasse pagamento: 29447637 de Pedro Jorge</MEMO>\n',
#  '          </STMTTRN>\n',
#  '          <STMTTRN>\n',
#  '            <TRNTYPE>DEBIT</TRNTYPE>\n',
#  '            <DTPOSTED>20180417120000[-3:BRT]</DTPOSTED>\n',
#  '            <TRNAMT>-3,34</TRNAMT>\n',
#  '            <FITID>2018041403361001046000000065642577</FITID>\n',
#  '            <CHECKNUM>000000065642577</CHECKNUM>\n',
#  '            <MEMO>Tarifa repasse: 29447637 de Pedro Jorge</MEMO>\n',
#  '          </STMTTRN>\n',
#  '          <STMTTRN>\n',
#  '            <TRNTYPE>CREDIT</TRNTYPE>\n',
#  '            <DTPOSTED>20180428120000[-3:BRT]</DTPOSTED>\n',
#  '            <TRNAMT>120,90</TRNAMT>\n',
#  '            <FITID>2018041421312002047000000065694866</FITID>\n',
#  '            <CHECKNUM>000000065694866</CHECKNUM>\n',
#  '            <REFNUM>2002047000000029517140</REFNUM>\n',
#  '            <MEMO>Repasse pagamento: 29517140 de Beltrano Diniz</MEMO>\n',
#  '          </STMTTRN>\n',
#  '          <STMTTRN>\n',
#  '            <TRNTYPE>DEBIT</TRNTYPE>\n',
#  '            <DTPOSTED>20180428120000[-3:BRT]</DTPOSTED>\n',
#  '            <TRNAMT>-7,23</TRNAMT>\n',
#  '            <FITID>2018041421311001047000000065694867</FITID>\n',
#  '            <CHECKNUM>000000065694867</CHECKNUM>\n',
#  '            <MEMO>Tarifa repasse: 29517140 de Beltrano Diniz</MEMO>\n',
#  '          </STMTTRN>\n',
#  '          <STMTTRN>\n',
#  '            <TRNTYPE>CREDIT</TRNTYPE>\n',
#  '            <DTPOSTED>20180429120000[-3:BRT]</DTPOSTED>\n',
#  '            <TRNAMT>55,80</TRNAMT>\n',
#  '            <FITID>2018041517302002047000000065696376</FITID>\n',
#  '            <CHECKNUM>000000065696376</CHECKNUM>\n',
#  '            <REFNUM>2002047000000029533821</REFNUM>\n',
#  '            <MEMO>Repasse pagamento: 29533821 de Henrique Almeida</MEMO>\n',
#  '          </STMTTRN>\n',
#  '          <STMTTRN>\n',
#  '            <TRNTYPE>DEBIT</TRNTYPE>\n',
#  '            <DTPOSTED>20180429120000[-3:BRT]</DTPOSTED>\n',
#  '            <TRNAMT>-3,49</TRNAMT>\n',
#  '            <FITID>2018041517301001047000000065696377</FITID>\n',
#  '            <CHECKNUM>000000065696377</CHECKNUM>\n',
#  '            <MEMO>Tarifa repasse: 29533821 de Henrique Almeida</MEMO>\n',
#  '          </STMTTRN>\n',
#  '          <STMTTRN>\n',
#  '            <TRNTYPE>CREDIT</TRNTYPE>\n',
#  '            <DTPOSTED>20180429120000[-3:BRT]</DTPOSTED>\n',
#  '            <TRNAMT>74,40</TRNAMT>\n',
#  '            <FITID>2018042606102002046000000066643667</FITID>\n',
#  '            <CHECKNUM>000000066643667</CHECKNUM>\n',
#  '            <REFNUM>2002046000000030830691</REFNUM>\n',
#  '            <MEMO>Repasse pagamento: 30830691 de Duque Alves</MEMO>\n',
#  '          </STMTTRN>\n',
#  '          <STMTTRN>\n',
#  '            <TRNTYPE>DEBIT</TRNTYPE>\n',
#  '            <DTPOSTED>20180429120000[-3:BRT]</DTPOSTED>\n',
#  '            <TRNAMT>-3,34</TRNAMT>\n',
#  '            <FITID>2018042606101001046000000066643670</FITID>\n',
#  '            <CHECKNUM>000000066643670</CHECKNUM>\n',
#  '            <MEMO>Tarifa repasse: 30830691 de Duque Alves</MEMO>\n',
#  '          </STMTTRN>\n',
#  '        </BANKTRANLIST>\n',
#  '        <LEDGERBAL>\n',
#  '          <BALAMT>635,50</BALAMT>\n',
#  '          <DTASOF>20180429120000[-3:BRT]</DTASOF>\n',
#  '        </LEDGERBAL>\n',
#  '      </STMTRS>\n',
#  '    </STMTTRNRS>\n',
#  '  </BANKMSGSRSV1>\n',
#  '</OFX>']

# %% [markdown]
# Como podemos fazer para imprimir as linhas do arquivo sem mostrar os caracteres de quebra de linha ('\n') como estão aparecendo em cada linha?

# %% [markdown]
# <p title='Cada vez que você usa a função readlines(), o ponteiro da linha do arquivo vai para a sua última linha, por isso, abra o arquivo novamente para reiniciar o ponteiro e tente iterar (percorrer) a lista, imprimindo cada linha'>Dica 1</p>

# %% [markdown]
# <p title='Você sabia que dá pra fazer isso numa única, linha? Usando List Comprehensions, sintaxe: [print(item) for item in items]'>Dica 2</p> <a href='https://blog.teamtreehouse.com/python-single-line-loops' target="_blank">Link</a>

# %% [markdown]
# <p title="Se você usar um segundo parâmetro na função print(..., end='') não haverá quebra de linha automaticamente e não aparecerão linhas em branco que originalmente não existem no arquivo">Dica 3</p>

# %% [markdown]
# Converta todas as linhas em uma única grande string (uma única variável contendo todas as palavras) e a armazene na variável 'text'
# * Mas neste caso não pode ser uma lista
# * Com a exceção de que uma string é uma lista de caracteres

# %% [markdown]
# <p title='Abra o arquivo novamente e tente usar função join'>Dica 1</p>
# <a href='https://www.geeksforgeeks.org/join-function-python/' target='_blank'>Link</a>

# %%
ofx = open(path)
lista = ofx.readlines()
for item in lista:
    print(item, end='')
# Out:
# OFXHEADER:100
# DATA:OFXSGML
# VERSION:102
# SECURITY:NONE
# ENCODING:UTF-8
# CHARSET:1252
# COMPRESSION:NONE
# OLDFILEUID:NONE
# NEWFILEUID:NONE
# <OFX>
#   <SIGNONMSGSRSV1>
#     <SONRS>
#       <STATUS>
#         <CODE>0</CODE>
#         <SEVERITY>INFO</SEVERITY>
#       </STATUS>
#       <DTSERVER>20180430120030[-3:BRT]</DTSERVER>
#       <LANGUAGE>POR</LANGUAGE>
#       <FI>
#         <ORG>Gerencianet</ORG>
#         <FID>gnt</FID>
#       </FI>
#     </SONRS>
#   </SIGNONMSGSRSV1>
#   <BANKMSGSRSV1>
#     <STMTTRNRS>
#       <TRNUID>1</TRNUID>
#       <STATUS>
#         <CODE>0</CODE>
#         <SEVERITY>INFO</SEVERITY>
#       </STATUS>
#       <STMTRS>
#         <CURDEF>BRL</CURDEF>
#         <BANKACCTFROM>
#           <BANKID>gnt</BANKID>
#           <ACCTID>1459950-11</ACCTID>
#           <ACCTTYPE>CHECKING</ACCTTYPE>
#         </BANKACCTFROM>
#         <BANKTRANLIST>
#           <DTSTART>20180130120000[-3:BRT]</DTSTART>
#           <DTEND>20180429120000[-3:BRT]</DTEND>
#           <STMTTRN>
#             <TRNTYPE>CREDIT</TRNTYPE>
#             <DTPOSTED>20180309120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>74,40</TRNAMT>
#             <FITID>2018030607232002046000000061553574</FITID>
#             <CHECKNUM>000000061553574</CHECKNUM>
#             <REFNUM>2002046000000017223405</REFNUM>
#             <MEMO>Repasse pagamento: 17223405 de Jorge Teixeira</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>DEBIT</TRNTYPE>
#             <DTPOSTED>20180309120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>-3,34</TRNAMT>
#             <FITID>2018030607231001046000000061553576</FITID>
#             <CHECKNUM>000000061553576</CHECKNUM>
#             <MEMO>Tarifa repasse: 17223405 de Jorge Teixeira</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>CREDIT</TRNTYPE>
#             <DTPOSTED>20180320120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>74,40</TRNAMT>
#             <FITID>2018031703312002046000000062976602</FITID>
#             <CHECKNUM>000000062976602</CHECKNUM>
#             <REFNUM>2002046000000022612776</REFNUM>
#             <MEMO>Repasse pagamento: 22612776 de Paulo Jorge Alves</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>DEBIT</TRNTYPE>
#             <DTPOSTED>20180320120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>-3,34</TRNAMT>
#             <FITID>2018031703311001046000000062976603</FITID>
#             <CHECKNUM>000000062976603</CHECKNUM>
#             <MEMO>Tarifa repasse: 22612776 de Paulo Jorge Alves</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>CREDIT</TRNTYPE>
#             <DTPOSTED>20180330120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>74,40</TRNAMT>
#             <FITID>2018032704142002046000000063575983</FITID>
#             <CHECKNUM>000000063575983</CHECKNUM>
#             <REFNUM>2002046000000028015595</REFNUM>
#             <MEMO>Repasse pagamento: 28015595 de Fulano Aguiar</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>DEBIT</TRNTYPE>
#             <DTPOSTED>20180330120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>-3,34</TRNAMT>
#             <FITID>2018032704141001046000000063575986</FITID>
#             <CHECKNUM>000000063575986</CHECKNUM>
#             <MEMO>Tarifa repasse: 28015595 de Fulano Aguiar</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>CREDIT</TRNTYPE>
#             <DTPOSTED>20180406120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>65,10</TRNAMT>
#             <FITID>2018040307262002046000000064109592</FITID>
#             <CHECKNUM>000000064109592</CHECKNUM>
#             <REFNUM>2002046000000028108174</REFNUM>
#             <MEMO>Repasse pagamento: 28108174 de Ciclano da Silva</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>DEBIT</TRNTYPE>
#             <DTPOSTED>20180406120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>-3,34</TRNAMT>
#             <FITID>2018040307261001046000000064109593</FITID>
#             <CHECKNUM>000000064109593</CHECKNUM>
#             <MEMO>Tarifa repasse: 28108174 de Ciclano da Silva</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>CREDIT</TRNTYPE>
#             <DTPOSTED>20180416120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>74,40</TRNAMT>
#             <FITID>2018041303342002046000000065551500</FITID>
#             <CHECKNUM>000000065551500</CHECKNUM>
#             <REFNUM>2002046000000029384993</REFNUM>
#             <MEMO>Repasse pagamento: 29384993 de Jorge Amado</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>DEBIT</TRNTYPE>
#             <DTPOSTED>20180416120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>-3,34</TRNAMT>
#             <FITID>2018041303341001046000000065551501</FITID>
#             <CHECKNUM>000000065551501</CHECKNUM>
#             <MEMO>Tarifa repasse: 29384993 de Jorge Amado</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>CREDIT</TRNTYPE>
#             <DTPOSTED>20180417120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>55,80</TRNAMT>
#             <FITID>2018041403362002046000000065642576</FITID>
#             <CHECKNUM>000000065642576</CHECKNUM>
#             <REFNUM>2002046000000029447637</REFNUM>
#             <MEMO>Repasse pagamento: 29447637 de Pedro Jorge</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>DEBIT</TRNTYPE>
#             <DTPOSTED>20180417120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>-3,34</TRNAMT>
#             <FITID>2018041403361001046000000065642577</FITID>
#             <CHECKNUM>000000065642577</CHECKNUM>
#             <MEMO>Tarifa repasse: 29447637 de Pedro Jorge</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>CREDIT</TRNTYPE>
#             <DTPOSTED>20180428120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>120,90</TRNAMT>
#             <FITID>2018041421312002047000000065694866</FITID>
#             <CHECKNUM>000000065694866</CHECKNUM>
#             <REFNUM>2002047000000029517140</REFNUM>
#             <MEMO>Repasse pagamento: 29517140 de Beltrano Diniz</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>DEBIT</TRNTYPE>
#             <DTPOSTED>20180428120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>-7,23</TRNAMT>
#             <FITID>2018041421311001047000000065694867</FITID>
#             <CHECKNUM>000000065694867</CHECKNUM>
#             <MEMO>Tarifa repasse: 29517140 de Beltrano Diniz</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>CREDIT</TRNTYPE>
#             <DTPOSTED>20180429120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>55,80</TRNAMT>
#             <FITID>2018041517302002047000000065696376</FITID>
#             <CHECKNUM>000000065696376</CHECKNUM>
#             <REFNUM>2002047000000029533821</REFNUM>
#             <MEMO>Repasse pagamento: 29533821 de Henrique Almeida</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>DEBIT</TRNTYPE>
#             <DTPOSTED>20180429120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>-3,49</TRNAMT>
#             <FITID>2018041517301001047000000065696377</FITID>
#             <CHECKNUM>000000065696377</CHECKNUM>
#             <MEMO>Tarifa repasse: 29533821 de Henrique Almeida</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>CREDIT</TRNTYPE>
#             <DTPOSTED>20180429120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>74,40</TRNAMT>
#             <FITID>2018042606102002046000000066643667</FITID>
#             <CHECKNUM>000000066643667</CHECKNUM>
#             <REFNUM>2002046000000030830691</REFNUM>
#             <MEMO>Repasse pagamento: 30830691 de Duque Alves</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>DEBIT</TRNTYPE>
#             <DTPOSTED>20180429120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>-3,34</TRNAMT>
#             <FITID>2018042606101001046000000066643670</FITID>
#             <CHECKNUM>000000066643670</CHECKNUM>
#             <MEMO>Tarifa repasse: 30830691 de Duque Alves</MEMO>
#           </STMTTRN>
#         </BANKTRANLIST>
#         <LEDGERBAL>
#           <BALAMT>635,50</BALAMT>
#           <DTASOF>20180429120000[-3:BRT]</DTASOF>
#         </LEDGERBAL>
#       </STMTRS>
#     </STMTTRNRS>
#   </BANKMSGSRSV1>
# </OFX>

# %%
lista 
text = ''

# %%
text = text.join(lista)

# %%
print(text)
# Out:
# OFXHEADER:100
# DATA:OFXSGML
# VERSION:102
# SECURITY:NONE
# ENCODING:UTF-8
# CHARSET:1252
# COMPRESSION:NONE
# OLDFILEUID:NONE
# NEWFILEUID:NONE
# <OFX>
#   <SIGNONMSGSRSV1>
#     <SONRS>
#       <STATUS>
#         <CODE>0</CODE>
#         <SEVERITY>INFO</SEVERITY>
#       </STATUS>
#       <DTSERVER>20180430120030[-3:BRT]</DTSERVER>
#       <LANGUAGE>POR</LANGUAGE>
#       <FI>
#         <ORG>Gerencianet</ORG>
#         <FID>gnt</FID>
#       </FI>
#     </SONRS>
#   </SIGNONMSGSRSV1>
#   <BANKMSGSRSV1>
#     <STMTTRNRS>
#       <TRNUID>1</TRNUID>
#       <STATUS>
#         <CODE>0</CODE>
#         <SEVERITY>INFO</SEVERITY>
#       </STATUS>
#       <STMTRS>
#         <CURDEF>BRL</CURDEF>
#         <BANKACCTFROM>
#           <BANKID>gnt</BANKID>
#           <ACCTID>1459950-11</ACCTID>
#           <ACCTTYPE>CHECKING</ACCTTYPE>
#         </BANKACCTFROM>
#         <BANKTRANLIST>
#           <DTSTART>20180130120000[-3:BRT]</DTSTART>
#           <DTEND>20180429120000[-3:BRT]</DTEND>
#           <STMTTRN>
#             <TRNTYPE>CREDIT</TRNTYPE>
#             <DTPOSTED>20180309120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>74,40</TRNAMT>
#             <FITID>2018030607232002046000000061553574</FITID>
#             <CHECKNUM>000000061553574</CHECKNUM>
#             <REFNUM>2002046000000017223405</REFNUM>
#             <MEMO>Repasse pagamento: 17223405 de Jorge Teixeira</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>DEBIT</TRNTYPE>
#             <DTPOSTED>20180309120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>-3,34</TRNAMT>
#             <FITID>2018030607231001046000000061553576</FITID>
#             <CHECKNUM>000000061553576</CHECKNUM>
#             <MEMO>Tarifa repasse: 17223405 de Jorge Teixeira</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>CREDIT</TRNTYPE>
#             <DTPOSTED>20180320120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>74,40</TRNAMT>
#             <FITID>2018031703312002046000000062976602</FITID>
#             <CHECKNUM>000000062976602</CHECKNUM>
#             <REFNUM>2002046000000022612776</REFNUM>
#             <MEMO>Repasse pagamento: 22612776 de Paulo Jorge Alves</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>DEBIT</TRNTYPE>
#             <DTPOSTED>20180320120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>-3,34</TRNAMT>
#             <FITID>2018031703311001046000000062976603</FITID>
#             <CHECKNUM>000000062976603</CHECKNUM>
#             <MEMO>Tarifa repasse: 22612776 de Paulo Jorge Alves</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>CREDIT</TRNTYPE>
#             <DTPOSTED>20180330120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>74,40</TRNAMT>
#             <FITID>2018032704142002046000000063575983</FITID>
#             <CHECKNUM>000000063575983</CHECKNUM>
#             <REFNUM>2002046000000028015595</REFNUM>
#             <MEMO>Repasse pagamento: 28015595 de Fulano Aguiar</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>DEBIT</TRNTYPE>
#             <DTPOSTED>20180330120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>-3,34</TRNAMT>
#             <FITID>2018032704141001046000000063575986</FITID>
#             <CHECKNUM>000000063575986</CHECKNUM>
#             <MEMO>Tarifa repasse: 28015595 de Fulano Aguiar</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>CREDIT</TRNTYPE>
#             <DTPOSTED>20180406120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>65,10</TRNAMT>
#             <FITID>2018040307262002046000000064109592</FITID>
#             <CHECKNUM>000000064109592</CHECKNUM>
#             <REFNUM>2002046000000028108174</REFNUM>
#             <MEMO>Repasse pagamento: 28108174 de Ciclano da Silva</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>DEBIT</TRNTYPE>
#             <DTPOSTED>20180406120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>-3,34</TRNAMT>
#             <FITID>2018040307261001046000000064109593</FITID>
#             <CHECKNUM>000000064109593</CHECKNUM>
#             <MEMO>Tarifa repasse: 28108174 de Ciclano da Silva</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>CREDIT</TRNTYPE>
#             <DTPOSTED>20180416120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>74,40</TRNAMT>
#             <FITID>2018041303342002046000000065551500</FITID>
#             <CHECKNUM>000000065551500</CHECKNUM>
#             <REFNUM>2002046000000029384993</REFNUM>
#             <MEMO>Repasse pagamento: 29384993 de Jorge Amado</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>DEBIT</TRNTYPE>
#             <DTPOSTED>20180416120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>-3,34</TRNAMT>
#             <FITID>2018041303341001046000000065551501</FITID>
#             <CHECKNUM>000000065551501</CHECKNUM>
#             <MEMO>Tarifa repasse: 29384993 de Jorge Amado</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>CREDIT</TRNTYPE>
#             <DTPOSTED>20180417120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>55,80</TRNAMT>
#             <FITID>2018041403362002046000000065642576</FITID>
#             <CHECKNUM>000000065642576</CHECKNUM>
#             <REFNUM>2002046000000029447637</REFNUM>
#             <MEMO>Repasse pagamento: 29447637 de Pedro Jorge</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>DEBIT</TRNTYPE>
#             <DTPOSTED>20180417120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>-3,34</TRNAMT>
#             <FITID>2018041403361001046000000065642577</FITID>
#             <CHECKNUM>000000065642577</CHECKNUM>
#             <MEMO>Tarifa repasse: 29447637 de Pedro Jorge</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>CREDIT</TRNTYPE>
#             <DTPOSTED>20180428120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>120,90</TRNAMT>
#             <FITID>2018041421312002047000000065694866</FITID>
#             <CHECKNUM>000000065694866</CHECKNUM>
#             <REFNUM>2002047000000029517140</REFNUM>
#             <MEMO>Repasse pagamento: 29517140 de Beltrano Diniz</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>DEBIT</TRNTYPE>
#             <DTPOSTED>20180428120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>-7,23</TRNAMT>
#             <FITID>2018041421311001047000000065694867</FITID>
#             <CHECKNUM>000000065694867</CHECKNUM>
#             <MEMO>Tarifa repasse: 29517140 de Beltrano Diniz</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>CREDIT</TRNTYPE>
#             <DTPOSTED>20180429120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>55,80</TRNAMT>
#             <FITID>2018041517302002047000000065696376</FITID>
#             <CHECKNUM>000000065696376</CHECKNUM>
#             <REFNUM>2002047000000029533821</REFNUM>
#             <MEMO>Repasse pagamento: 29533821 de Henrique Almeida</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>DEBIT</TRNTYPE>
#             <DTPOSTED>20180429120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>-3,49</TRNAMT>
#             <FITID>2018041517301001047000000065696377</FITID>
#             <CHECKNUM>000000065696377</CHECKNUM>
#             <MEMO>Tarifa repasse: 29533821 de Henrique Almeida</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>CREDIT</TRNTYPE>
#             <DTPOSTED>20180429120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>74,40</TRNAMT>
#             <FITID>2018042606102002046000000066643667</FITID>
#             <CHECKNUM>000000066643667</CHECKNUM>
#             <REFNUM>2002046000000030830691</REFNUM>
#             <MEMO>Repasse pagamento: 30830691 de Duque Alves</MEMO>
#           </STMTTRN>
#           <STMTTRN>
#             <TRNTYPE>DEBIT</TRNTYPE>
#             <DTPOSTED>20180429120000[-3:BRT]</DTPOSTED>
#             <TRNAMT>-3,34</TRNAMT>
#             <FITID>2018042606101001046000000066643670</FITID>
#             <CHECKNUM>000000066643670</CHECKNUM>
#             <MEMO>Tarifa repasse: 30830691 de Duque Alves</MEMO>
#           </STMTTRN>
#         </BANKTRANLIST>
#         <LEDGERBAL>
#           <BALAMT>635,50</BALAMT>
#           <DTASOF>20180429120000[-3:BRT]</DTASOF>
#         </LEDGERBAL>
#       </STMTRS>
#     </STMTTRNRS>
#   </BANKMSGSRSV1>
# </OFX>

# %% [markdown]
# Tendo a string em mãos, podemos usar o framework que já utilizamos para fazer nossas <i>queries</i> (consultas) em css selector ou xpath. Para isso, damos import na biblioteca:

# %%
import scrapy

# %% [markdown]
# Criamos um selector com a grande string:

# %%
selector = scrapy.selector.Selector(text=text)

# %%
selector
# Out:
# <Selector xpath=None data='<html><body><p>OFXHEADER:100\nDATA:OFX...'>

# %%
uglyxml = selector.get()

# %% [markdown]
# Mas vamos usar a seguinte função para imprimir o documento XML de forma hierárquica, para facilitar a nossa análise do documento.

# %%
import xml.dom.minidom

def prettify(uglyxml):
    pretty = xml.dom.minidom.parseString(uglyxml)
    print(pretty.toprettyxml())

# %%
prettify(uglyxml)
# Out:
# <?xml version="1.0" ?>
# <html>
# 	<body>
# 		<p>
# 			OFXHEADER:100
# DATA:OFXSGML
# VERSION:102
# SECURITY:NONE
# ENCODING:UTF-8
# CHARSET:1252
# COMPRESSION:NONE
# OLDFILEUID:NONE
# NEWFILEUID:NONE
#
# 			<ofx>
#
#
# 				<signonmsgsrsv1>
#
#
# 					<sonrs>
#
#
# 						<status>
#
#
# 							<code>0</code>
#
#
# 							<severity>INFO</severity>
#
#
# 						</status>
#
#
# 						<dtserver>20180430120030[-3:BRT]</dtserver>
#
#
# 						<language>POR</language>
#
#
# 						<fi>
#
#
# 							<org>Gerencianet</org>
#
#
# 							<fid>gnt</fid>
#
#
# 						</fi>
#
#
# 					</sonrs>
#
#
# 				</signonmsgsrsv1>
#
#
# 				<bankmsgsrsv1>
#
#
# 					<stmttrnrs>
#
#
# 						<trnuid>1</trnuid>
#
#
# 						<status>
#
#
# 							<code>0</code>
#
#
# 							<severity>INFO</severity>
#
#
# 						</status>
#
#
# 						<stmtrs>
#
#
# 							<curdef>BRL</curdef>
#
#
# 							<bankacctfrom>
#
#
# 								<bankid>gnt</bankid>
#
#
# 								<acctid>1459950-11</acctid>
#
#
# 								<accttype>CHECKING</accttype>
#
#
# 							</bankacctfrom>
#
#
# 							<banktranlist>
#
#
# 								<dtstart>20180130120000[-3:BRT]</dtstart>
#
#
# 								<dtend>20180429120000[-3:BRT]</dtend>
#
#
# 								<stmttrn>
#
#
# 									<trntype>CREDIT</trntype>
#
#
# 									<dtposted>20180309120000[-3:BRT]</dtposted>
#
#
# 									<trnamt>74,40</trnamt>
#
#
# 									<fitid>2018030607232002046000000061553574</fitid>
#
#
# 									<checknum>000000061553574</checknum>
#
#
# 									<refnum>2002046000000017223405</refnum>
#
#
# 									<memo>Repasse pagamento: 17223405 de Jorge Teixeira</memo>
#
#
# 								</stmttrn>
#
#
# 								<stmttrn>
#
#
# 									<trntype>DEBIT</trntype>
#
#
# 									<dtposted>20180309120000[-3:BRT]</dtposted>
#
#
# 									<trnamt>-3,34</trnamt>
#
#
# 									<fitid>2018030607231001046000000061553576</fitid>
#
#
# 									<checknum>000000061553576</checknum>
#
#
# 									<memo>Tarifa repasse: 17223405 de Jorge Teixeira</memo>
#
#
# 								</stmttrn>
#
#
# 								<stmttrn>
#
#
# 									<trntype>CREDIT</trntype>
#
#
# 									<dtposted>20180320120000[-3:BRT]</dtposted>
#
#
# 									<trnamt>74,40</trnamt>
#
#
# 									<fitid>2018031703312002046000000062976602</fitid>
#
#
# 									<checknum>000000062976602</checknum>
#
#
# 									<refnum>2002046000000022612776</refnum>
#
#
# 									<memo>Repasse pagamento: 22612776 de Paulo Jorge Alves</memo>
#
#
# 								</stmttrn>
#
#
# 								<stmttrn>
#
#
# 									<trntype>DEBIT</trntype>
#
#
# 									<dtposted>20180320120000[-3:BRT]</dtposted>
#
#
# 									<trnamt>-3,34</trnamt>
#
#
# 									<fitid>2018031703311001046000000062976603</fitid>
#
#
# 									<checknum>000000062976603</checknum>
#
#
# 									<memo>Tarifa repasse: 22612776 de Paulo Jorge Alves</memo>
#
#
# 								</stmttrn>
#
#
# 								<stmttrn>
#
#
# 									<trntype>CREDIT</trntype>
#
#
# 									<dtposted>20180330120000[-3:BRT]</dtposted>
#
#
# 									<trnamt>74,40</trnamt>
#
#
# 									<fitid>2018032704142002046000000063575983</fitid>
#
#
# 									<checknum>000000063575983</checknum>
#
#
# 									<refnum>2002046000000028015595</refnum>
#
#
# 									<memo>Repasse pagamento: 28015595 de Fulano Aguiar</memo>
#
#
# 								</stmttrn>
#
#
# 								<stmttrn>
#
#
# 									<trntype>DEBIT</trntype>
#
#
# 									<dtposted>20180330120000[-3:BRT]</dtposted>
#
#
# 									<trnamt>-3,34</trnamt>
#
#
# 									<fitid>2018032704141001046000000063575986</fitid>
#
#
# 									<checknum>000000063575986</checknum>
#
#
# 									<memo>Tarifa repasse: 28015595 de Fulano Aguiar</memo>
#
#
# 								</stmttrn>
#
#
# 								<stmttrn>
#
#
# 									<trntype>CREDIT</trntype>
#
#
# 									<dtposted>20180406120000[-3:BRT]</dtposted>
#
#
# 									<trnamt>65,10</trnamt>
#
#
# 									<fitid>2018040307262002046000000064109592</fitid>
#
#
# 									<checknum>000000064109592</checknum>
#
#
# 									<refnum>2002046000000028108174</refnum>
#
#
# 									<memo>Repasse pagamento: 28108174 de Ciclano da Silva</memo>
#
#
# 								</stmttrn>
#
#
# 								<stmttrn>
#
#
# 									<trntype>DEBIT</trntype>
#
#
# 									<dtposted>20180406120000[-3:BRT]</dtposted>
#
#
# 									<trnamt>-3,34</trnamt>
#
#
# 									<fitid>2018040307261001046000000064109593</fitid>
#
#
# 									<checknum>000000064109593</checknum>
#
#
# 									<memo>Tarifa repasse: 28108174 de Ciclano da Silva</memo>
#
#
# 								</stmttrn>
#
#
# 								<stmttrn>
#
#
# 									<trntype>CREDIT</trntype>
#
#
# 									<dtposted>20180416120000[-3:BRT]</dtposted>
#
#
# 									<trnamt>74,40</trnamt>
#
#
# 									<fitid>2018041303342002046000000065551500</fitid>
#
#
# 									<checknum>000000065551500</checknum>
#
#
# 									<refnum>2002046000000029384993</refnum>
#
#
# 									<memo>Repasse pagamento: 29384993 de Jorge Amado</memo>
#
#
# 								</stmttrn>
#
#
# 								<stmttrn>
#
#
# 									<trntype>DEBIT</trntype>
#
#
# 									<dtposted>20180416120000[-3:BRT]</dtposted>
#
#
# 									<trnamt>-3,34</trnamt>
#
#
# 									<fitid>2018041303341001046000000065551501</fitid>
#
#
# 									<checknum>000000065551501</checknum>
#
#
# 									<memo>Tarifa repasse: 29384993 de Jorge Amado</memo>
#
#
# 								</stmttrn>
#
#
# 								<stmttrn>
#
#
# 									<trntype>CREDIT</trntype>
#
#
# 									<dtposted>20180417120000[-3:BRT]</dtposted>
#
#
# 									<trnamt>55,80</trnamt>
#
#
# 									<fitid>2018041403362002046000000065642576</fitid>
#
#
# 									<checknum>000000065642576</checknum>
#
#
# 									<refnum>2002046000000029447637</refnum>
#
#
# 									<memo>Repasse pagamento: 29447637 de Pedro Jorge</memo>
#
#
# 								</stmttrn>
#
#
# 								<stmttrn>
#
#
# 									<trntype>DEBIT</trntype>
#
#
# 									<dtposted>20180417120000[-3:BRT]</dtposted>
#
#
# 									<trnamt>-3,34</trnamt>
#
#
# 									<fitid>2018041403361001046000000065642577</fitid>
#
#
# 									<checknum>000000065642577</checknum>
#
#
# 									<memo>Tarifa repasse: 29447637 de Pedro Jorge</memo>
#
#
# 								</stmttrn>
#
#
# 								<stmttrn>
#
#
# 									<trntype>CREDIT</trntype>
#
#
# 									<dtposted>20180428120000[-3:BRT]</dtposted>
#
#
# 									<trnamt>120,90</trnamt>
#
#
# 									<fitid>2018041421312002047000000065694866</fitid>
#
#
# 									<checknum>000000065694866</checknum>
#
#
# 									<refnum>2002047000000029517140</refnum>
#
#
# 									<memo>Repasse pagamento: 29517140 de Beltrano Diniz</memo>
#
#
# 								</stmttrn>
#
#
# 								<stmttrn>
#
#
# 									<trntype>DEBIT</trntype>
#
#
# 									<dtposted>20180428120000[-3:BRT]</dtposted>
#
#
# 									<trnamt>-7,23</trnamt>
#
#
# 									<fitid>2018041421311001047000000065694867</fitid>
#
#
# 									<checknum>000000065694867</checknum>
#
#
# 									<memo>Tarifa repasse: 29517140 de Beltrano Diniz</memo>
#
#
# 								</stmttrn>
#
#
# 								<stmttrn>
#
#
# 									<trntype>CREDIT</trntype>
#
#
# 									<dtposted>20180429120000[-3:BRT]</dtposted>
#
#
# 									<trnamt>55,80</trnamt>
#
#
# 									<fitid>2018041517302002047000000065696376</fitid>
#
#
# 									<checknum>000000065696376</checknum>
#
#
# 									<refnum>2002047000000029533821</refnum>
#
#
# 									<memo>Repasse pagamento: 29533821 de Henrique Almeida</memo>
#
#
# 								</stmttrn>
#
#
# 								<stmttrn>
#
#
# 									<trntype>DEBIT</trntype>
#
#
# 									<dtposted>20180429120000[-3:BRT]</dtposted>
#
#
# 									<trnamt>-3,49</trnamt>
#
#
# 									<fitid>2018041517301001047000000065696377</fitid>
#
#
# 									<checknum>000000065696377</checknum>
#
#
# 									<memo>Tarifa repasse: 29533821 de Henrique Almeida</memo>
#
#
# 								</stmttrn>
#
#
# 								<stmttrn>
#
#
# 									<trntype>CREDIT</trntype>
#
#
# 									<dtposted>20180429120000[-3:BRT]</dtposted>
#
#
# 									<trnamt>74,40</trnamt>
#
#
# 									<fitid>2018042606102002046000000066643667</fitid>
#
#
# 									<checknum>000000066643667</checknum>
#
#
# 									<refnum>2002046000000030830691</refnum>
#
#
# 									<memo>Repasse pagamento: 30830691 de Duque Alves</memo>
#
#
# 								</stmttrn>
#
#
# 								<stmttrn>
#
#
# 									<trntype>DEBIT</trntype>
#
#
# 									<dtposted>20180429120000[-3:BRT]</dtposted>
#
#
# 									<trnamt>-3,34</trnamt>
#
#
# 									<fitid>2018042606101001046000000066643670</fitid>
#
#
# 									<checknum>000000066643670</checknum>
#
#
# 									<memo>Tarifa repasse: 30830691 de Duque Alves</memo>
#
#
# 								</stmttrn>
#
#
# 							</banktranlist>
#
#
# 							<ledgerbal>
#
#
# 								<balamt>635,50</balamt>
#
#
# 								<dtasof>20180429120000[-3:BRT]</dtasof>
#
#
# 							</ledgerbal>
#
#
# 						</stmtrs>
#
#
# 					</stmttrnrs>
#
#
# 				</bankmsgsrsv1>
#
#
# 			</ofx>
# 		</p>
# 	</body>
# </html>

# %% [markdown]
# Use o seletor criado anteriormente para tentar extrair todas as transações do documento:

# %% [markdown]
# <p title='Lembre-se que scraping se resume a capturar a parte de código que contém tudo que interessa e iterar sobre essas partes maiores para, a partir delas, coletar as partes mais específicas'>Dica 1</p>

# %% [markdown]
# <p title='Já que o seletor retorna uma lista, acesse alguns items da lista com seu índice [1], [2] e [3] por exemplo, e use o extract() para alimentar a função prettify e mostrar o que você coletou'>Dica 2</p>

# %%
selector.css('stmttrn').extract()
# Out:
# ['<stmttrn>\n            <trntype>CREDIT</trntype>\n            <dtposted>20180309120000[-3:BRT]</dtposted>\n            <trnamt>74,40</trnamt>\n            <fitid>2018030607232002046000000061553574</fitid>\n            <checknum>000000061553574</checknum>\n            <refnum>2002046000000017223405</refnum>\n            <memo>Repasse pagamento: 17223405 de Jorge Teixeira</memo>\n          </stmttrn>',
#  '<stmttrn>\n            <trntype>DEBIT</trntype>\n            <dtposted>20180309120000[-3:BRT]</dtposted>\n            <trnamt>-3,34</trnamt>\n            <fitid>2018030607231001046000000061553576</fitid>\n            <checknum>000000061553576</checknum>\n            <memo>Tarifa repasse: 17223405 de Jorge Teixeira</memo>\n          </stmttrn>',
#  '<stmttrn>\n            <trntype>CREDIT</trntype>\n            <dtposted>20180320120000[-3:BRT]</dtposted>\n            <trnamt>74,40</trnamt>\n            <fitid>2018031703312002046000000062976602</fitid>\n            <checknum>000000062976602</checknum>\n            <refnum>2002046000000022612776</refnum>\n            <memo>Repasse pagamento: 22612776 de Paulo Jorge Alves</memo>\n          </stmttrn>',
#  '<stmttrn>\n            <trntype>DEBIT</trntype>\n            <dtposted>20180320120000[-3:BRT]</dtposted>\n            <trnamt>-3,34</trnamt>\n            <fitid>2018031703311001046000000062976603</fitid>\n            <checknum>000000062976603</checknum>\n            <memo>Tarifa repasse: 22612776 de Paulo Jorge Alves</memo>\n          </stmttrn>',
#  '<stmttrn>\n            <trntype>CREDIT</trntype>\n            <dtposted>20180330120000[-3:BRT]</dtposted>\n            <trnamt>74,40</trnamt>\n            <fitid>2018032704142002046000000063575983</fitid>\n            <checknum>000000063575983</checknum>\n            <refnum>2002046000000028015595</refnum>\n            <memo>Repasse pagamento: 28015595 de Fulano Aguiar</memo>\n          </stmttrn>',
#  '<stmttrn>\n            <trntype>DEBIT</trntype>\n            <dtposted>20180330120000[-3:BRT]</dtposted>\n            <trnamt>-3,34</trnamt>\n            <fitid>2018032704141001046000000063575986</fitid>\n            <checknum>000000063575986</checknum>\n            <memo>Tarifa repasse: 28015595 de Fulano Aguiar</memo>\n          </stmttrn>',
#  '<stmttrn>\n            <trntype>CREDIT</trntype>\n            <dtposted>20180406120000[-3:BRT]</dtposted>\n            <trnamt>65,10</trnamt>\n            <fitid>2018040307262002046000000064109592</fitid>\n            <checknum>000000064109592</checknum>\n            <refnum>2002046000000028108174</refnum>\n            <memo>Repasse pagamento: 28108174 de Ciclano da Silva</memo>\n          </stmttrn>',
#  '<stmttrn>\n            <trntype>DEBIT</trntype>\n            <dtposted>20180406120000[-3:BRT]</dtposted>\n            <trnamt>-3,34</trnamt>\n            <fitid>2018040307261001046000000064109593</fitid>\n            <checknum>000000064109593</checknum>\n            <memo>Tarifa repasse: 28108174 de Ciclano da Silva</memo>\n          </stmttrn>',
#  '<stmttrn>\n            <trntype>CREDIT</trntype>\n            <dtposted>20180416120000[-3:BRT]</dtposted>\n            <trnamt>74,40</trnamt>\n            <fitid>2018041303342002046000000065551500</fitid>\n            <checknum>000000065551500</checknum>\n            <refnum>2002046000000029384993</refnum>\n            <memo>Repasse pagamento: 29384993 de Jorge Amado</memo>\n          </stmttrn>',
#  '<stmttrn>\n            <trntype>DEBIT</trntype>\n            <dtposted>20180416120000[-3:BRT]</dtposted>\n            <trnamt>-3,34</trnamt>\n            <fitid>2018041303341001046000000065551501</fitid>\n            <checknum>000000065551501</checknum>\n            <memo>Tarifa repasse: 29384993 de Jorge Amado</memo>\n          </stmttrn>',
#  '<stmttrn>\n            <trntype>CREDIT</trntype>\n            <dtposted>20180417120000[-3:BRT]</dtposted>\n            <trnamt>55,80</trnamt>\n            <fitid>2018041403362002046000000065642576</fitid>\n            <checknum>000000065642576</checknum>\n            <refnum>2002046000000029447637</refnum>\n            <memo>Repasse pagamento: 29447637 de Pedro Jorge</memo>\n          </stmttrn>',
#  '<stmttrn>\n            <trntype>DEBIT</trntype>\n            <dtposted>20180417120000[-3:BRT]</dtposted>\n            <trnamt>-3,34</trnamt>\n            <fitid>2018041403361001046000000065642577</fitid>\n            <checknum>000000065642577</checknum>\n            <memo>Tarifa repasse: 29447637 de Pedro Jorge</memo>\n          </stmttrn>',
#  '<stmttrn>\n            <trntype>CREDIT</trntype>\n            <dtposted>20180428120000[-3:BRT]</dtposted>\n            <trnamt>120,90</trnamt>\n            <fitid>2018041421312002047000000065694866</fitid>\n            <checknum>000000065694866</checknum>\n            <refnum>2002047000000029517140</refnum>\n            <memo>Repasse pagamento: 29517140 de Beltrano Diniz</memo>\n          </stmttrn>',
#  '<stmttrn>\n            <trntype>DEBIT</trntype>\n            <dtposted>20180428120000[-3:BRT]</dtposted>\n            <trnamt>-7,23</trnamt>\n            <fitid>2018041421311001047000000065694867</fitid>\n            <checknum>000000065694867</checknum>\n            <memo>Tarifa repasse: 29517140 de Beltrano Diniz</memo>\n          </stmttrn>',
#  '<stmttrn>\n            <trntype>CREDIT</trntype>\n            <dtposted>20180429120000[-3:BRT]</dtposted>\n            <trnamt>55,80</trnamt>\n            <fitid>2018041517302002047000000065696376</fitid>\n            <checknum>000000065696376</checknum>\n            <refnum>2002047000000029533821</refnum>\n            <memo>Repasse pagamento: 29533821 de Henrique Almeida</memo>\n          </stmttrn>',
#  '<stmttrn>\n            <trntype>DEBIT</trntype>\n            <dtposted>20180429120000[-3:BRT]</dtposted>\n            <trnamt>-3,49</trnamt>\n            <fitid>2018041517301001047000000065696377</fitid>\n            <checknum>000000065696377</checknum>\n            <memo>Tarifa repasse: 29533821 de Henrique Almeida</memo>\n          </stmttrn>',
#  '<stmttrn>\n            <trntype>CREDIT</trntype>\n            <dtposted>20180429120000[-3:BRT]</dtposted>\n            <trnamt>74,40</trnamt>\n            <fitid>2018042606102002046000000066643667</fitid>\n            <checknum>000000066643667</checknum>\n            <refnum>2002046000000030830691</refnum>\n            <memo>Repasse pagamento: 30830691 de Duque Alves</memo>\n          </stmttrn>',
#  '<stmttrn>\n            <trntype>DEBIT</trntype>\n            <dtposted>20180429120000[-3:BRT]</dtposted>\n            <trnamt>-3,34</trnamt>\n            <fitid>2018042606101001046000000066643670</fitid>\n            <checknum>000000066643670</checknum>\n            <memo>Tarifa repasse: 30830691 de Duque Alves</memo>\n          </stmttrn>']

# %% [markdown]
# Procure um elemento externo às transacoes que contenha o saldo do mês anterior e a data de referência

# %% [markdown]
# <p title='Tem a ver com balanço financeiro'>Dica 1</p>

# %%
prettify(selector.css('ledgerbal').extract_first())
#selector.css('ledgerbal::text').extract_first()
# Out:
# <?xml version="1.0" ?>
# <ledgerbal>
#
#
# 	<balamt>635,50</balamt>
#
#
# 	<dtasof>20180429120000[-3:BRT]</dtasof>
#
#
# </ledgerbal>

# %% [markdown]
# Extraia somente a data de referência sem tags

# %% [markdown]
# <p title='Em <tag>texto</tag>, usando o css selector tag::text você vai capturar somente a palavra "texto" que está dentro da tag '>Dica 1</p>

# %%
referencia = selector.css('dtasof::text').extract_first()

# %%
referencia
# Out:
# '20180429120000[-3:BRT]'

# %% [markdown]
# Armazene na variável 'referencia' a data no seguinte formato: ano-mes-dia, ex.: 2019-12-01

# %%
referencia = referencia[0:4]+'-'+referencia[4:6]+'-'+referencia[6:8]

# %%
referencia
# Out:
# '2018-04-29'

# %% [markdown]
# Complete a seguinte função, para extrair as informações específicas de cada transação, passando a data de referência que você extraiu como parâmetro:
# * O 'None' do if não deve ser alterado
# * Caso o seu extrato não possui transações em moedas estrangeiras, usar o elemento 'currate' para extrair quando houver, usando o extract_first() para não lançar uma exceção.

# %%
def extrair_transacao(transacao_selector, referencia):
    data = transacao_selector.css('dtposted::text').extract_first() 
    descricao = transacao_selector.css('memo::text').extract_first()  
    taxa = None
    valor = transacao_selector.css('trnamt::text').extract_first()  
    return {'date': data[0:4]+'-'+data[4:6]+'-'+data[6:8],
            'descricao': descricao,
            'valor': valor if taxa is None else round(float(valor)*float(taxa), ndigits=2),
            'referencia': referencia}

# %% [markdown]
# Teste a funcão que você acabou de implementar, usando um seletor para um item da lista de transções:

# %%
extrair_transacao(selector.css('stmttrn')[1], referencia)
# Out:
# {'date': '2018-03-09',
#  'descricao': 'Tarifa repasse: 17223405 de Jorge Teixeira',
#  'valor': '-3,34',
#  'referencia': '2018-04-29'}

# %% [markdown]
# Exemplo de resultado esperado:
#
# ```python
# {'date': '2019-09-11',
#  'descricao': 'DEBITOS NO EXTERIOR CONVERT P/ R$',
#  'valor': -9.09,
#  'referencia': '2019-10-10'}
# ```

# %% [markdown]
# Agora faça o teste para as 10 primeiras transações do seu mês de referência:

# %%
for i in range(0,9):
    posicao = extrair_transacao(selector.css('stmttrn')[i], referencia)
    print(posicao)
# Out:
# {'date': '2018-03-09', 'descricao': 'Repasse pagamento: 17223405 de Jorge Teixeira', 'valor': '74,40', 'referencia': '2018-04-29'}
# {'date': '2018-03-09', 'descricao': 'Tarifa repasse: 17223405 de Jorge Teixeira', 'valor': '-3,34', 'referencia': '2018-04-29'}
# {'date': '2018-03-20', 'descricao': 'Repasse pagamento: 22612776 de Paulo Jorge Alves', 'valor': '74,40', 'referencia': '2018-04-29'}
# {'date': '2018-03-20', 'descricao': 'Tarifa repasse: 22612776 de Paulo Jorge Alves', 'valor': '-3,34', 'referencia': '2018-04-29'}
# {'date': '2018-03-30', 'descricao': 'Repasse pagamento: 28015595 de Fulano Aguiar', 'valor': '74,40', 'referencia': '2018-04-29'}
# {'date': '2018-03-30', 'descricao': 'Tarifa repasse: 28015595 de Fulano Aguiar', 'valor': '-3,34', 'referencia': '2018-04-29'}
# {'date': '2018-04-06', 'descricao': 'Repasse pagamento: 28108174 de Ciclano da Silva', 'valor': '65,10', 'referencia': '2018-04-29'}
# {'date': '2018-04-06', 'descricao': 'Tarifa repasse: 28108174 de Ciclano da Silva', 'valor': '-3,34', 'referencia': '2018-04-29'}
# {'date': '2018-04-16', 'descricao': 'Repasse pagamento: 29384993 de Jorge Amado', 'valor': '74,40', 'referencia': '2018-04-29'}

# %% [markdown]
# Exemplo de resultado esperado:
#
# ```python
# {'date': '2019-09-10', 'descricao': 'AJUSTE A CREDITO VAR.CAMBIAL COMPRA EXT', 'valor': '8.82', 'referencia': '2019-12-31'}
# {'date': '2019-09-11', 'descricao': 'DEBITOS PAGOS EM USS NO PERIODO', 'valor': 9.09, 'referencia': '2019-12-31'}
# {'date': '2019-09-11', 'descricao': 'DEBITOS NO EXTERIOR CONVERT P/ R$', 'valor': -9.09, 'referencia': '2019-12-31'}
# {'date': '2019-09-10', 'descricao': 'PGTO DEBITO CONTA 1617 000005071  200211', 'valor': '3167.31', 'referencia': '2019-12-31'}
# {'date': '2019-09-07', 'descricao': 'COURSRAWQ82BME1NNCQV6  6502657649    CA', 'valor': -213.15, 'referencia': '2019-12-31'}
# {'date': '2019-09-09', 'descricao': 'IOF - COMPRA NO EXTERIOR', 'valor': -13.62, 'referencia': '2019-12-31'}
# {'date': '2019-08-31', 'descricao': 'OLD PUB                Joao Pessoa   BR', 'valor': '-56.00', 'referencia': '2019-12-31'}
# {'date': '2019-09-22', 'descricao': 'CINEPOLIS MANAIRA      JOAO PESSOA   BR', 'valor': '-62.00', 'referencia': '2019-12-31'}
# {'date': '2019-08-29', 'descricao': 'THE GARAGE             Joao Pessoa   BR', 'valor': '-35.00', 'referencia': '2019-12-31'}
# {'date': '2019-08-31', 'descricao': 'OTR PUB SERVICOS DE BA JOAO PESSOA   BR', 'valor': '-16.00', 'referencia': '2019-12-31'}
# ```

# %% [markdown]
# Gere uma lista com todas as transações:

# %%
for i in range(0,len(selector.css('stmttrn').extract())):
    item = extrair_transacao(selector.css('stmttrn')[i], referencia)
    print(item)
# Out:
# {'date': '2018-03-09', 'descricao': 'Repasse pagamento: 17223405 de Jorge Teixeira', 'valor': '74,40', 'referencia': '2018-04-29'}
# {'date': '2018-03-09', 'descricao': 'Tarifa repasse: 17223405 de Jorge Teixeira', 'valor': '-3,34', 'referencia': '2018-04-29'}
# {'date': '2018-03-20', 'descricao': 'Repasse pagamento: 22612776 de Paulo Jorge Alves', 'valor': '74,40', 'referencia': '2018-04-29'}
# {'date': '2018-03-20', 'descricao': 'Tarifa repasse: 22612776 de Paulo Jorge Alves', 'valor': '-3,34', 'referencia': '2018-04-29'}
# {'date': '2018-03-30', 'descricao': 'Repasse pagamento: 28015595 de Fulano Aguiar', 'valor': '74,40', 'referencia': '2018-04-29'}
# {'date': '2018-03-30', 'descricao': 'Tarifa repasse: 28015595 de Fulano Aguiar', 'valor': '-3,34', 'referencia': '2018-04-29'}
# {'date': '2018-04-06', 'descricao': 'Repasse pagamento: 28108174 de Ciclano da Silva', 'valor': '65,10', 'referencia': '2018-04-29'}
# {'date': '2018-04-06', 'descricao': 'Tarifa repasse: 28108174 de Ciclano da Silva', 'valor': '-3,34', 'referencia': '2018-04-29'}
# {'date': '2018-04-16', 'descricao': 'Repasse pagamento: 29384993 de Jorge Amado', 'valor': '74,40', 'referencia': '2018-04-29'}
# {'date': '2018-04-16', 'descricao': 'Tarifa repasse: 29384993 de Jorge Amado', 'valor': '-3,34', 'referencia': '2018-04-29'}
# {'date': '2018-04-17', 'descricao': 'Repasse pagamento: 29447637 de Pedro Jorge', 'valor': '55,80', 'referencia': '2018-04-29'}
# {'date': '2018-04-17', 'descricao': 'Tarifa repasse: 29447637 de Pedro Jorge', 'valor': '-3,34', 'referencia': '2018-04-29'}
# {'date': '2018-04-28', 'descricao': 'Repasse pagamento: 29517140 de Beltrano Diniz', 'valor': '120,90', 'referencia': '2018-04-29'}
# {'date': '2018-04-28', 'descricao': 'Tarifa repasse: 29517140 de Beltrano Diniz', 'valor': '-7,23', 'referencia': '2018-04-29'}
# {'date': '2018-04-29', 'descricao': 'Repasse pagamento: 29533821 de Henrique Almeida', 'valor': '55,80', 'referencia': '2018-04-29'}
# {'date': '2018-04-29', 'descricao': 'Tarifa repasse: 29533821 de Henrique Almeida', 'valor': '-3,49', 'referencia': '2018-04-29'}
# {'date': '2018-04-29', 'descricao': 'Repasse pagamento: 30830691 de Duque Alves', 'valor': '74,40', 'referencia': '2018-04-29'}
# {'date': '2018-04-29', 'descricao': 'Tarifa repasse: 30830691 de Duque Alves', 'valor': '-3,34', 'referencia': '2018-04-29'}

# %%
lista = []
for i in range(0,len(selector.css('stmttrn').extract())):
    lista.append(extrair_transacao(selector.css('stmttrn')[i], referencia))

#lista = [extrair_transacao(transacao, referencia) for transacao in selector.css('stmttrn')]

# %%
lista
#for i in range(0,len(selector.css('stmttrn'))):
#    posicao = extrair_transacao(selector.css('stmttrn')[i], referencia)
#    print(posicao)
# Out:
# [{'date': '2018-03-09',
#   'descricao': 'Repasse pagamento: 17223405 de Jorge Teixeira',
#   'valor': '74,40',
#   'referencia': '2018-04-29'},
#  {'date': '2018-03-09',
#   'descricao': 'Tarifa repasse: 17223405 de Jorge Teixeira',
#   'valor': '-3,34',
#   'referencia': '2018-04-29'},
#  {'date': '2018-03-20',
#   'descricao': 'Repasse pagamento: 22612776 de Paulo Jorge Alves',
#   'valor': '74,40',
#   'referencia': '2018-04-29'},
#  {'date': '2018-03-20',
#   'descricao': 'Tarifa repasse: 22612776 de Paulo Jorge Alves',
#   'valor': '-3,34',
#   'referencia': '2018-04-29'},
#  {'date': '2018-03-30',
#   'descricao': 'Repasse pagamento: 28015595 de Fulano Aguiar',
#   'valor': '74,40',
#   'referencia': '2018-04-29'},
#  {'date': '2018-03-30',
#   'descricao': 'Tarifa repasse: 28015595 de Fulano Aguiar',
#   'valor': '-3,34',
#   'referencia': '2018-04-29'},
#  {'date': '2018-04-06',
#   'descricao': 'Repasse pagamento: 28108174 de Ciclano da Silva',
#   'valor': '65,10',
#   'referencia': '2018-04-29'},
#  {'date': '2018-04-06',
#   'descricao': 'Tarifa repasse: 28108174 de Ciclano da Silva',
#   'valor': '-3,34',
#   'referencia': '2018-04-29'},
#  {'date': '2018-04-16',
#   'descricao': 'Repasse pagamento: 29384993 de Jorge Amado',
#   'valor': '74,40',
#   'referencia': '2018-04-29'},
#  {'date': '2018-04-16',
#   'descricao': 'Tarifa repasse: 29384993 de Jorge Amado',
#   'valor': '-3,34',
#   'referencia': '2018-04-29'},
#  {'date': '2018-04-17',
#   'descricao': 'Repasse pagamento: 29447637 de Pedro Jorge',
#   'valor': '55,80',
#   'referencia': '2018-04-29'},
#  {'date': '2018-04-17',
#   'descricao': 'Tarifa repasse: 29447637 de Pedro Jorge',
#   'valor': '-3,34',
#   'referencia': '2018-04-29'},
#  {'date': '2018-04-28',
#   'descricao': 'Repasse pagamento: 29517140 de Beltrano Diniz',
#   'valor': '120,90',
#   'referencia': '2018-04-29'},
#  {'date': '2018-04-28',
#   'descricao': 'Tarifa repasse: 29517140 de Beltrano Diniz',
#   'valor': '-7,23',
#   'referencia': '2018-04-29'},
#  {'date': '2018-04-29',
#   'descricao': 'Repasse pagamento: 29533821 de Henrique Almeida',
#   'valor': '55,80',
#   'referencia': '2018-04-29'},
#  {'date': '2018-04-29',
#   'descricao': 'Tarifa repasse: 29533821 de Henrique Almeida',
#   'valor': '-3,49',
#   'referencia': '2018-04-29'},
#  {'date': '2018-04-29',
#   'descricao': 'Repasse pagamento: 30830691 de Duque Alves',
#   'valor': '74,40',
#   'referencia': '2018-04-29'},
#  {'date': '2018-04-29',
#   'descricao': 'Tarifa repasse: 30830691 de Duque Alves',
#   'valor': '-3,34',
#   'referencia': '2018-04-29'}]

# %% [markdown]
# Exemplo de resultado esperado:
#
# ```python
# [{'date': '2019-09-10',
#   'descricao': 'AJUSTE A CREDITO VAR.CAMBIAL COMPRA EXT',
#   'valor': '8.82',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-11',
#   'descricao': 'DEBITOS PAGOS EM USS NO PERIODO',
#   'valor': 9.09,
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-11',
#   'descricao': 'DEBITOS NO EXTERIOR CONVERT P/ R$',
#   'valor': -9.09,
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-10',
#   'descricao': 'PGTO DEBITO CONTA 1617 000005071  200211',
#   'valor': '3167.31',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-07',
#   'descricao': 'COURSRAWQ82BME1NNCQV6  6502657649    CA',
#   'valor': -213.15,
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-09',
#   'descricao': 'IOF - COMPRA NO EXTERIOR',
#   'valor': -13.62,
#   'referencia': '2019-12-31'},
#  {'date': '2019-08-31',
#   'descricao': 'OLD PUB                Joao Pessoa   BR',
#   'valor': '-56.00',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-22',
#   'descricao': 'CINEPOLIS MANAIRA      JOAO PESSOA   BR',
#   'valor': '-62.00',
#   'referencia': '2019-12-31'},
#  {'date': '2019-08-29',
#   'descricao': 'THE GARAGE             Joao Pessoa   BR',
#   'valor': '-35.00',
#   'referencia': '2019-12-31'},
#  {'date': '2019-08-31',
#   'descricao': 'OTR PUB SERVICOS DE BA JOAO PESSOA   BR',
#   'valor': '-16.00',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-01',
#   'descricao': 'ACAI DA VILLA          Joao Pessoa   BR',
#   'valor': '-20.27',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-11',
#   'descricao': 'GOLD STRIKE MANGABEIRA Joao Pessoa   BR',
#   'valor': '-14.00',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-13',
#   'descricao': 'NAU FRUTOS DO MAR      JOAO PESSOA   BR',
#   'valor': '-110.90',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-14',
#   'descricao': 'TERROA BUFFET SERVICOS JOAO PESSOA   BR',
#   'valor': '-72.00',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-14',
#   'descricao': 'CHOPP TIME             JOAO PESSOA   BR',
#   'valor': '-80.00',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-15',
#   'descricao': 'BISNAGAO               Joao Pessoa   BR',
#   'valor': '-21.50',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-15',
#   'descricao': 'CHOPP TIME             JOAO PESSOA   BR',
#   'valor': '-91.00',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-15',
#   'descricao': 'CHOPP TIME             JOAO PESSOA   BR',
#   'valor': '-12.00',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-22',
#   'descricao': 'MC DONALDS  JPM        JOAO PESSOA   BR',
#   'valor': '-33.50',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-12',
#   'descricao': 'FCIA PAGUE MENOS 126   JOAO PESSOA   BR',
#   'valor': '-61.80',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-13',
#   'descricao': 'REDE PHARMA            JOAO PESSOA   BR',
#   'valor': '-14.99',
#   'referencia': '2019-12-31'},
#  {'date': '2019-08-30',
#   'descricao': 'POSTO TEXACO EXPRESSO  JOAO PESSOA   BR',
#   'valor': '-176.79',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-05',
#   'descricao': 'LIVRARIA NOVO DIA      JOAO PESSOA   BR',
#   'valor': '-21.90',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-07',
#   'descricao': 'POSTO TANQUE CHEIO     JOAO PESSOA   BR',
#   'valor': '-54.95',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-13',
#   'descricao': 'PAG*AlexandreBarbosa   JOAOPESSOA    BR',
#   'valor': '-11.00',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-13',
#   'descricao': 'PAG*AlexandreBarbosa   JOAOPESSOA    BR',
#   'valor': '-11.00',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-18',
#   'descricao': 'POSTO TANQUE CHEIO     JOAO PESSOA   BR',
#   'valor': '-62.37',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-18',
#   'descricao': 'EPML DE INTERNET2333280PARIS         FR',
#   'valor': -165.43,
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-20',
#   'descricao': 'IOF - COMPRA NO EXTERIOR',
#   'valor': -10.57,
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-18',
#   'descricao': 'EPML DE INTERNET2333280PARIS         FR',
#   'valor': -48.63,
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-20',
#   'descricao': 'IOF - COMPRA NO EXTERIOR',
#   'valor': -3.09,
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-21',
#   'descricao': 'NETFLIX.COM            SAO PAULO     BR',
#   'valor': '-32.90',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-18',
#   'descricao': 'REDE MENOR PRECO       JOAO PESSOA   BR',
#   'valor': '-28.04',
#   'referencia': '2019-12-31'},
#  {'date': '2019-08-28',
#   'descricao': 'Uber Do Brasil TecnologSAO PAULO     BR',
#   'valor': '-20.99',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-09',
#   'descricao': 'Uber Do Brasil TecnologSAO PAULO     BR',
#   'valor': '-22.13',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-18',
#   'descricao': 'MERCPAGO*JHACESSORIOS  OSASCO        BR',
#   'valor': '-59.89',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-18',
#   'descricao': 'MERCPAGO*VISIONCENTER  OSASCO        BR',
#   'valor': '-316.02',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-02',
#   'descricao': 'HOTELSCOM8073378255750 SAO PAULO     BR',
#   'valor': '-494.54',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-02',
#   'descricao': 'HOTELSCOM8000590413218 SAO PAULO     BR',
#   'valor': '-246.77',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-25',
#   'descricao': 'PROTECAO OURO OUT/2019               BR',
#   'valor': '-3.00',
#   'referencia': '2019-12-31'},
#  {'date': '2019-09-13',
#   'descricao': 'EBANX SPOTIFY          Curitiba      BR',
#   'valor': '-26.90',
#   'referencia': '2019-12-31'},
#  {'date': '2019-07-09',
#   'descricao': 'OTICA DINIZ   PARC 03/04 JOAO PESSOA BR',
#   'valor': '-101.50',
#   'referencia': '2019-12-31'},
#  {'date': '2019-07-09',
#   'descricao': 'BAG TO YOU    PARC 03/04 JOAO PESSOA BR',
#   'valor': '-175.00',
#   'referencia': '2019-12-31'},
#  {'date': '2019-07-10',
#   'descricao': 'MIRANDA COMPU PARC 03/10 JOAO PESSOA BR',
#   'valor': '-34.90',
#   'referencia': '2019-12-31'},
#  {'date': '2019-07-10',
#   'descricao': 'CENTAURO - CE PARC 03/10 JOAO PESSOA BR',
#   'valor': '-79.99',
#   'referencia': '2019-12-31'},
#  {'date': '2019-08-10',
#   'descricao': 'HNA*OBOTICARI PARC 02/02 CURITIBA    BR',
#   'valor': '-121.20',
#   'referencia': '2019-12-31'}]
# ```

# %% [markdown]
# Transforme essa lista de dicionários python 'lista', equivalentes ao formato json em um arquivo json de fato:

# %%
import json
with open('../../mes.json', 'w') as fout:
    json.dump(lista , fout, indent=4)

# %% [markdown]
# ## Tarefas 01 concluída
