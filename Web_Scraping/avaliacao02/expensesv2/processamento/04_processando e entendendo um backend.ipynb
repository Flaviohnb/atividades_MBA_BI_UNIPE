# %% [markdown]
# ## Captura e Visualização de dados

# %% [markdown]
# <b>Professor:</b> Diénert Vieira
# <b>Telefone:</b> (83) 9 8182-1479
# <b>Email:</b> dienertalencar@gmail.com

# %% [markdown]
# ### Segunda avaliação de aprendizagem

# %% [markdown]
# Depois de extrairmos os dados bancários, passamos para a sua análise. Podemos detectar padrões de comportcamentos e gerar visualizações que nos auxiliem na tomada de decisões.

# %% [markdown]
# ### Tarefa 04
# #### Processar dados para exibir num frontend

# %% [markdown]
# Primeiro importamos a biblioteca de manipulação de dados: Pandas. E usamos um alias (apelido): pd, por brevidade:

# %%
import pandas as pd

# %% [markdown]
# Depois podemos listar os arquivos do diretório:

# %%
df = pd.read_json("../dados/tudo.json")
dateformat = '%Y/%m/%d'

df['date'] = pd.to_datetime(df['date'], format=dateformat)
df['referencia'] = pd.to_datetime(df['referencia'], format=dateformat)
df.index = df.date
#df = df.drop(columns='date')
#df = df.sort_index()
df
# Out:
#                  date                                          descricao  \
# date
# 2020-01-27 2020-01-27  COMPRA CARTAO MAESTRO              27/01 BRICK...
# 2020-01-27 2020-01-27  COMPRA CARTAO MAESTRO              27/01 STUDI...
# 2020-01-29 2020-01-29  COMPRA CARTAO MAESTRO              29/01 GALER...
# 2020-01-29 2020-01-29  COMPRA CARTAO MAESTRO              29/01 STUDI...
# 2020-01-30 2020-01-30  COMPRA CARTAO MAESTRO              30/01 REPUB...
# 2020-01-31 2020-01-31  COMPRA CARTAO MAESTRO              31/01 MARE ...
# 2020-01-31 2020-01-31  COMPRA CARTAO MAESTRO              31/01 STUDI...
# 2020-01-31 2020-01-31  COMPRA CARTAO MAESTRO              31/01 STUDI...
# 2020-02-03 2020-02-03  COMPRA CARTAO MAESTRO              03/02 BUSIN...
# 2020-02-03 2020-02-03  COMPRA CARTAO MAESTRO              03/02 STUDI...
# 2020-02-04 2020-02-04  COMPRA CARTAO MAESTRO              04/02 BRICK...
# 2020-02-05 2020-02-05  COMPRA CARTAO MAESTRO              05/02 BRICK...
# 2020-02-05 2020-02-05  COMPRA CARTAO MAESTRO              05/02 STUDI...
# 2020-02-06 2020-02-06  CREDITO DE SALARIO                 INDRA BRAS ...
# 2020-02-06 2020-02-06  COMPRA CARTAO MAESTRO              06/02 BUSIN...
# 2020-02-06 2020-02-06  COMPRA CARTAO MAESTRO              06/02 POSTO...
# 2020-02-06 2020-02-06  TED MESMA TITULARIDADE CIP         001-4996-00...
# 2020-02-06 2020-02-06  COMPRA CARTAO MAESTRO              06/02 BARBE...
# 2020-02-07 2020-02-07  TARIFA TEDELETRONICO               06/02/2020\...
# 2020-02-07 2020-02-07  COMPRA CARTAO MAESTRO              07/02 ALL P...
# 2020-02-07 2020-02-07  COMPRA CARTAO MAESTRO              07/02 GALER...
# 2020-02-07 2020-02-07  COMPRA CARTAO MAESTRO              07/02 IPE\n...
# 2020-02-07 2020-02-07  COMPRA CARTAO MAESTRO              07/02 SUBWA...
# 2020-02-07 2020-02-07         REMUNERACAO CONTAMAX CDB DI\n \t\t\t\t\t\t
# 2020-02-10 2020-02-10  COMPRA CARTAO MAESTRO              08/02 NOVO ...
# 2020-02-10 2020-02-10  COMPRA CARTAO MAESTRO              08/02 STELO...
# 2020-02-13    -2.50 2020-02-26
# 2020-02-14   -20.00 2020-02-26
# 2020-02-14    -3.50 2020-02-26
# 2020-02-17    -3.00 2020-02-26
# 2020-02-18    27.90 2020-02-26
# 2020-02-18   -14.12 2020-02-26
# 2020-02-19    -7.50 2020-02-26
# 2020-02-20   -12.00 2020-02-26
# 2020-02-26    -6.00 2020-02-26
# 2020-02-26   -22.90 2020-02-26
# 2020-02-26    -9.99 2020-02-26
# 2020-02-26    -5.00 2020-02-26
# 2020-02-26    -6.46 2020-02-26
# 2020-02-26   -23.08 2020-02-26
# 2020-02-26   -11.20 2020-02-26

# %%
def filtra_e_soma(df, descricao):
    filtrado = df[df.descricao.str.lower().str.count(descricao) > 0]
    print('Soma: ', filtrado.valor.sum())
    return filtrado.copy()

# %%
def salva_serie(filtrado, inverte=True):
    filtrado_por_data = filtrado.groupby([filtrado.index.date]).valor.sum() * (-1 if inverte else 1) 
    filtrado_por_data = filtrado_por_data.to_frame()
    filtrado_por_data['day'] = filtrado_por_data.index
    filtrado_por_data.columns = ['count', 'day']
    filtrado_por_data = filtrado_por_data.reset_index()
    filtrado_por_data = filtrado_por_data[['day', 'count']]
    filtrado_por_data.to_csv('../frontends/calendario_horizontal/dates.csv', index=False)
    return filtrado_por_data

# %%
def filtra_e_salva(df, descricao):
    filtrado = filtra_e_soma(df, descricao)
    return salva_serie(filtrado)

# %%
filtra_e_salva(df, ' ')
# Out:
# Soma:  -77.65999999999953
#            day   count
# 0   2020-01-27   19.50
# 1   2020-01-29   23.64
# 2   2020-01-30   17.81
# 3   2020-01-31   40.50
# 4   2020-02-03   15.00
# 5   2020-02-04    6.00
# 6   2020-02-05    9.00
# 7   2020-02-06 -907.22
# 8   2020-02-07  476.05
# 9   2020-02-10  216.13
# 10  2020-02-12   41.90
# 11  2020-02-13    2.50
# 12  2020-02-14   23.50
# 13  2020-02-17    3.00
# 14  2020-02-18  -13.78
# 15  2020-02-19    7.50
# 16  2020-02-20   12.00
# 17  2020-02-26   84.63

# %%
filtra_e_salva(df, '^posto ')

# %%
filtra_e_salva(df, 'spotify')

# %% [markdown]
# Agora vá para o diretório de frontends, pela linha de comando, entre no diretório "calendario_horizontal" e execute o comando: python -m http.server 80

# %% [markdown]
# Acesse no browser http://localhost/ e veja os dias em que você realizou abastecimentos ao longo do ano.

# %% [markdown]
# Repita o processo para o termo que desejar

# %% [markdown]
# ### Agora preparamos os dados para uma aplicação React

# %%
from calendar import monthrange
from datetime import date, datetime

def separa_mes(df, month, year):
    begin = datetime(year, month, 1)
    end = datetime(year, month, monthrange(year, month)[1])
    return df[df.date.ge(begin) & df.date.le(end)].copy()

# %%
import json

# %%
max_date = mes.date.max()
month = max_date.month
year = max_date.year

# %%
month = 12

# %%
year = 2019

# %%
df
# Out:
#                  date                                          descricao  \
# date
# 2020-01-27 2020-01-27  COMPRA CARTAO MAESTRO              27/01 BRICK...
# 2020-01-27 2020-01-27  COMPRA CARTAO MAESTRO              27/01 STUDI...
# 2020-01-29 2020-01-29  COMPRA CARTAO MAESTRO              29/01 GALER...
# 2020-01-29 2020-01-29  COMPRA CARTAO MAESTRO              29/01 STUDI...
# 2020-02-26 2020-02-26  COMPRA CARTAO MAESTRO              24/02 GIRAF...
# 2020-02-26 2020-02-26  COMPRA CARTAO MAESTRO              24/02 LOJAS...
# 2020-02-26 2020-02-26  COMPRA CARTAO MAESTRO              24/02 MAG A...
# 2020-02-26 2020-02-26  COMPRA CARTAO MAESTRO              24/02 PANIF...
# 2020-02-26 2020-02-26  COMPRA CARTAO MAESTRO              26/02 JP JD...
# 2020-02-26 2020-02-26  COMPRA CARTAO MAESTRO              26/02 PANIF...
#
#               valor referencia
# date
# 2020-01-27    -6.00 2020-02-26
# 2020-01-27   -13.50 2020-02-26
# 2020-01-29   -17.64 2020-02-26
# 2020-01-29    -6.00 2020-02-26
# 2020-01-30   -17.81 2020-02-26
# 2020-01-31   -23.00 2020-02-26
# 2020-01-31    -6.00 2020-02-26
# 2020-01-31   -11.50 2020-02-26
# 2020-02-03    -6.00 2020-02-26
# 2020-02-03    -9.00 2020-02-26
# 2020-02-04    -6.00 2020-02-26
# 2020-02-05    -6.00 2020-02-26
# 2020-02-05    -3.00 2020-02-26
# 2020-02-06  2658.80 2020-02-26
# 2020-02-06    -6.00 2020-02-26
# 2020-02-06  -210.58 2020-02-26
# 2020-02-06 -1500.00 2020-02-26
# 2020-02-06   -35.00 2020-02-26
# 2020-02-07    -8.24 2020-02-26
# 2020-02-07  -100.00 2020-02-26
# 2020-02-07   -24.11 2020-02-26
# 2020-02-07  -330.40 2020-02-26
# 2020-02-07   -13.50 2020-02-26
# 2020-02-07     0.20 2020-02-26
# 2020-02-10   -16.87 2020-02-26
# 2020-02-10    -3.50 2020-02-26
# 2020-02-10   -17.50 2020-02-26
# 2020-02-10    -8.20 2020-02-26
# 2020-02-10  -170.06 2020-02-26
# 2020-02-12    -6.00 2020-02-26
# 2020-02-12   -21.00 2020-02-26
# 2020-02-12   -14.90 2020-02-26
# 2020-02-13    -2.50 2020-02-26
# 2020-02-14   -20.00 2020-02-26
# 2020-02-14    -3.50 2020-02-26
# 2020-02-17    -3.00 2020-02-26
# 2020-02-18    27.90 2020-02-26
# 2020-02-18   -14.12 2020-02-26
# 2020-02-19    -7.50 2020-02-26
# 2020-02-20   -12.00 2020-02-26
# 2020-02-26    -6.00 2020-02-26
# 2020-02-26   -22.90 2020-02-26
# 2020-02-26    -9.99 2020-02-26
# 2020-02-26    -5.00 2020-02-26
# 2020-02-26    -6.46 2020-02-26
# 2020-02-26   -23.08 2020-02-26
# 2020-02-26   -11.20 2020-02-26

# %%
mes = separa_mes(df, month, year)
mes = mes[['date', 'descricao', 'valor']]
mes.columns = ['Trans Date', 'Description', 'Amount']
mes['Trans Date'] = mes['Trans Date'].astype(str)
text = json.dumps(mes.to_dict(orient='records'), indent=4, ensure_ascii=True)
file = open('../frontends/expensesv2/src/data/expenses.json', 'w')
file.write(text)
# Out:
# 2

# %%
print(text)
# Out:
# []

# %% [markdown]
# * Instale o Node.js: https://nodejs.org/en/ (LTS)
# * Entre no diretório frontedns/expensesv2 pela linha de comando
# * Execute o comando: npm install
# * Ao terminar o anterior, execute: npm start
# * O comando anterior deve abrir o browser automaticamente em http://localhost:3000/

# %% [markdown]
# <img align='center' src='imagens/congrats.png'>
