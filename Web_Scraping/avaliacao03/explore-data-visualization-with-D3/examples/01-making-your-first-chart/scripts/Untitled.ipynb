# %%
import pandas as pd
import json
import numpy as np

# %% [markdown]
# Lendo o arquivo desta forma para tratar os quando houverem registros (dias) com campos ausentes

# %%
text=open('./my_weather_data_fahrenheit.json','r')
x=text.read()

y=json.loads(x)
df=pd.DataFrame(y)

# %%
df.head()
# Out:
#          time  sunriseTime  sunsetTime  moonPhase  temperatureHigh  \
# 0  1547434800   1547453700  1547498640       0.27            90.44
# 1  1547521200   1547540100  1547585100       0.31            89.28
# 2  1547607600   1547626560  1547671500       0.34            90.50
# 3  1547694000   1547712960  1547757900       0.38            89.74
# 4  1547780400   1547799420  1547844300       0.41            89.50
#
#    temperatureHighTime  temperatureLow  temperatureLowTime  \
# 0           1547484900           74.99          1547514000
# 1           1547568060           75.74          1547624580
# 2           1547654280           77.38          1547701380
# 3           1547740440           76.95          1547790240
# 4           1547827320           76.69          1547883060
#
#    apparentTemperatureHigh  apparentTemperatureHighTime  ...  \
# 0                    98.71                   1547484780  ...
# 1                    95.79                   1547567880  ...
# ...

# %%
df.describe()
# Out:
#                time   sunriseTime    sunsetTime   moonPhase  temperatureHigh  \
# count  3.650000e+02  3.650000e+02  3.650000e+02  365.000000       365.000000
# mean   1.563160e+09  1.563179e+09  1.563222e+09    0.499041        86.427479
# std    9.116121e+06  9.115599e+06  9.115930e+06    0.284051         2.507817
# min    1.547435e+09  1.547454e+09  1.547499e+09    0.000000        79.130000
# 25%    1.555297e+09  1.555317e+09  1.555360e+09    0.260000        84.440000
# 50%    1.563160e+09  1.563180e+09  1.563222e+09    0.500000        86.800000
# 75%    1.571022e+09  1.571040e+09  1.571084e+09    0.740000        88.540000
# max    1.578884e+09  1.578903e+09  1.578948e+09    0.990000        91.530000
#
#        temperatureHighTime  temperatureLow  temperatureLowTime  \
# count         3.650000e+02      365.000000        3.650000e+02
# mean          1.563204e+09       74.773699        1.563256e+09
# std           9.115246e+06        2.088078        9.113609e+06
# ...

# %%
temperatures = [column for column in df.columns if column.count('emperature') > 0 and column.count('ime') == 0]
temperatures
# Out:
# ['temperatureHigh',
#  'temperatureLow',
#  'apparentTemperatureHigh',
#  'apparentTemperatureLow',
#  'temperatureMin',
#  'temperatureMax',
#  'apparentTemperatureMin',
#  'apparentTemperatureMax']

# %%
def apply(registro):
    return registro.apply(lambda x: round((x - 32) * 5/9, ndigits=2))

# %%
df[temperatures].head()
# Out:
#    temperatureHigh  temperatureLow  apparentTemperatureHigh  \
# 0            90.44           74.99                    98.71
# 1            89.28           75.74                    95.79
# 2            90.50           77.38                    98.57
# 3            89.74           76.95                    97.94
# 4            89.50           76.69                    97.15
#
#    apparentTemperatureLow  temperatureMin  temperatureMax  \
# 0                   76.86           74.99           90.44
# 1                   77.78           76.61           89.28
# 2                   79.38           75.74           90.50
# 3                   78.94           77.38           89.74
# 4                   78.61           76.95           89.50
#
#    apparentTemperatureMin  apparentTemperatureMax
# 0                   76.86                   98.71
# 1                   78.36                   95.79
# 2                   77.78                   98.57
# ...

# %%
df[temperatures] = df[temperatures].apply(apply, axis=1)

# %%
df[temperatures]
# Out:
#      temperatureHigh  temperatureLow  apparentTemperatureHigh  \
# 0              32.47           23.88                    37.06
# 1              31.82           24.30                    35.44
# 2              32.50           25.21                    36.98
# 3              32.08           24.97                    36.63
# 4              31.94           24.83                    36.19
# ..               ...             ...                      ...
# 360            30.34           24.83                    34.32
# 361            31.13           24.51                    34.12
# 362            31.33           23.91                    34.78
# 363            31.28           24.80                    34.25
# 364            31.59           25.43                    36.32
#
#      apparentTemperatureLow  temperatureMin  temperatureMax  \
# 0                     24.92           23.88           32.47
# 1                     25.43           24.78           31.82
# ...

# %%
df.head()
# Out:
#          time  sunriseTime  sunsetTime  moonPhase  temperatureHigh  \
# 0  1547434800   1547453700  1547498640       0.27            32.47
# 1  1547521200   1547540100  1547585100       0.31            31.82
# 2  1547607600   1547626560  1547671500       0.34            32.50
# 3  1547694000   1547712960  1547757900       0.38            32.08
# 4  1547780400   1547799420  1547844300       0.41            31.94
#
#    temperatureHighTime  temperatureLow  temperatureLowTime  \
# 0           1547484900           23.88          1547514000
# 1           1547568060           24.30          1547624580
# 2           1547654280           25.21          1547701380
# 3           1547740440           24.97          1547790240
# 4           1547827320           24.83          1547883060
#
#    apparentTemperatureHigh  apparentTemperatureHighTime  ...  \
# 0                    37.06                   1547484780  ...
# 1                    35.44                   1547567880  ...
# ...

# %%
df.describe()
# Out:
#                time   sunriseTime    sunsetTime   moonPhase  temperatureHigh  \
# count  3.650000e+02  3.650000e+02  3.650000e+02  365.000000       365.000000
# mean   1.563160e+09  1.563179e+09  1.563222e+09    0.499041        30.237397
# std    9.116121e+06  9.115599e+06  9.115930e+06    0.284051         1.393529
# min    1.547435e+09  1.547454e+09  1.547499e+09    0.000000        26.180000
# 25%    1.555297e+09  1.555317e+09  1.555360e+09    0.260000        29.130000
# 50%    1.563160e+09  1.563180e+09  1.563222e+09    0.500000        30.440000
# 75%    1.571022e+09  1.571040e+09  1.571084e+09    0.740000        31.410000
# max    1.578884e+09  1.578903e+09  1.578948e+09    0.990000        33.070000
#
#        temperatureHighTime  temperatureLow  temperatureLowTime  \
# count         3.650000e+02      365.000000        3.650000e+02
# mean          1.563204e+09       23.763096        1.563256e+09
# std           9.115246e+06        1.160211        9.113609e+06
# ...

# %%
df.to_json('./my_weather_data.json', orient='records')
